# %%
# !pip3 install quarto-cli
# Out:
# ...
#   Using cached quarto_cli-1.6.42.tar.gz (4.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# ...
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# ...
#   error: subprocess-exited-with-error
#
#   × Building wheel for quarto-cli (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [123 lines of output]
#       /private/var/folders/7c/6mwcpn092nv2b_hdssqpr8vw0000gn/T/pip-build-env-gbajo_u3/overlay/lib/python3.13/site-packages/setuptools/config/_apply_pyprojecttoml.py:82: SetuptoolsDeprecationWarning: `project.license` as a TOML table is deprecated
#       !!
#
#               ********************************************************************************
# ...

# %%
# !quarto render "Report.ipynb"
# Out:
# pandoc
#   to: html
#   output-file: Report.html
#   standalone: true
#   embed-resources: true
#   self-contained: true
#   section-divs: true
#   html-math-method: mathjax
#   wrap: none
#   default-image-extension: png
#   toc: true
#
# metadata
#   document-css: false
#   link-citations: true
#   date-format: long
#   lang: en
#   title: 'The Price of Neglect: A Global Look at Child Deprivation'
#   author: Simran Dureja
#   fontsize: 16px
#   linestretch: 1.5
#   theme: sandstone
#
# Output created: Report.html
